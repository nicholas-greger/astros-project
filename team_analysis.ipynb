# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import xticks
plt.rcParams['figure.figsize'] = (30,15)

# %%
df1 = pd.read_csv('astros batting data 2017.csv')
df1
# Out:
#       Rk  Gtm    Date Unnamed: 3  Opp    Rslt  PA  AB   R   H  ...  SB  CS  \
# 0      1    1   3-Apr        NaN  SEA   W,3-0  30  27   3   6  ...   1   0
# 1      2    2   4-Apr        NaN  SEA   W,2-1  29  26   2   5  ...   0   2
# 2      3    3   5-Apr        NaN  SEA   W,5-3  55  51   5  13  ...   0   0
# 3      4    4   6-Apr        NaN  SEA   L,2-4  36  32   2   6  ...   0   0
# 4      5    5   7-Apr        NaN  KCR   L,1-5  33  30   1   6  ...   0   0
# ..   ...  ...     ...        ...  ...     ...  ..  ..  ..  ..  ...  ..  ..
# 157  158  158  27-Sep          @  TEX  W,12-2  45  43  12  16  ...   0   0
# 158  159  159  28-Sep          @  BOS  W,12-2  50  44  12  17  ...   0   0
# 159  160  160  29-Sep          @  BOS   W,3-2  36  33   3   6  ...   0   1
# 160  161  161  30-Sep          @  BOS   L,3-6  37  33   3   8  ...   0   1
# 161  162  162   1-Oct          @  BOS   W,4-3  38  33   4   8  ...   1   0
#
#         BA    OBP    SLG    OPS  LOB   #  Thr  Opp. Starter (GmeSc)
# 0    0.222  0.241  0.444  0.686    3  10    R       F.Hernandez(55)
# 1    0.208  0.259  0.434  0.693    3  10    R         H.Iwakuma(55)
# 2    0.231  0.277  0.413  0.690   12  11    L          J.Paxton(72)
# 3    0.221  0.277  0.404  0.681    7  11    L         A.Miranda(50)
# 4    0.217  0.276  0.373  0.650    5  10    L          J.Vargas(61)
# ..     ...    ...    ...    ...  ...  ..  ...                   ...
# 157  0.282  0.345  0.479  0.824    6  14    R        N.Martinez(24)
# 158  0.283  0.346  0.481  0.827   11  16    L       E.Rodriguez(23)
# 159  0.282  0.346  0.480  0.825    6  11    R          D.Fister(50)
# 160  0.282  0.346  0.479  0.825    7  11    L        D.Pomeranz(63)
# 161  0.282  0.346  0.478  0.823    7  12    R       H.Velazquez(58)
#
# [162 rows x 32 columns]

# %%
plt.plot_date(df1['Date'], df1['BA'])
xticks([3, 27, 56, 83, 107, 135, 162], ['April', 'May', 'June', 'July', 'August', 'September', 'October'])
plt.title('Date vs. Batting Average (BA)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Batting Average (BA)', fontsize = 20)
# Out:
# Text(0, 0.5, 'Batting Average (BA)')

# %%
print(df1['BA'].mean())
# Out:
# 0.27733950617283953

# %% [markdown]
# ## An obvious increase in the Batting Average occurs around the same time as the sign stealing campaign began. This is one initial observation that could have a serious foundation in the logic of the cheating scandal.

# %%
plt.plot_date(df1['Date'], df1['RBI'], '-')
xticks([3, 27, 56, 83, 107, 135, 162], ['April', 'May', 'June', 'July', 'August', 'September', 'October'])
plt.title('Date vs. Runs Batted In (RBI)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Runs Batted In (RBI)', fontsize = 20)
# Out:
# Text(0, 0.5, 'Runs Batted In (RBI)')

# %%
print(df1['RBI'].mean())
# Out:
# 5.271604938271605

# %% [markdown]
# ## RBIs seemed to increase in the middle of the season but also died off a bit as the playoffs approached.

# %%
plt.plot_date(df1['Date'], df1['H'], '-')
xticks([3, 27, 56, 83, 107, 135, 162], ['April', 'May', 'June', 'July', 'August', 'September', 'October'])
plt.title('Date vs. Hits (H)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Hits (H)', fontsize = 20)
# Out:
# Text(0, 0.5, 'Hits (H)')

# %%
print(df1['H'].mean())
# Out:
# 9.75925925925926

# %% [markdown]
# ## The number of hits increased around the May 21st scandal beginning and remained relatively consistent for the remainder of the season.

# %%
plt.plot_date(df1['Date'], df1['OBP'])
xticks([3, 27, 56, 83, 107, 135, 162], ['April', 'May', 'June', 'July', 'August', 'September', 'October'])
plt.title('Date vs. On Base Percentage (OBP)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('On Base Percentage (OBP)', fontsize = 20)
# Out:
# Text(0, 0.5, 'On Base Percentage (OBP)')

# %%
print(df1['OBP'].mean())
# Out:
# 0.34321604938271605

# %% [markdown]
# ## Seeing as how the cheating began around May 21st, it is interesting how the rest of the season is relatively consistent when compared to the beginning of the season. Could this be a product of cheating or just finding more consistency with a team throughout a season?

# %%
plt.plot_date(df1['Date'], df1['AB'], '-')
xticks([3, 27, 56, 83, 107, 135, 162], ['April', 'May', 'June', 'July', 'August', 'September', 'October'])
plt.title('Date vs. At-Bats (AB)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('At-Bats (AB)', fontsize = 20)
# Out:
# Text(0, 0.5, 'At-Bats (AB)')

# %%
print(df1['AB'].mean())
# Out:
# 34.635802469135804

# %%
df2 = pd.read_csv('astros_bangs_20200127.csv')
df2
# Out:
#                          game_id  game_pk  game_date opponent  \
# 0     2017_04_03_seamlb_houmlb_1   490111   3/4/2017      SEA
# 1     2017_04_03_seamlb_houmlb_1   490111   3/4/2017      SEA
# 2     2017_04_03_seamlb_houmlb_1   490111   3/4/2017      SEA
# 3     2017_04_03_seamlb_houmlb_1   490111   3/4/2017      SEA
# 4     2017_04_03_seamlb_houmlb_1   490111   3/4/2017      SEA
# ...                          ...      ...        ...      ...
# 8269  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
# 8270  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
# 8271  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
# 8272  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
# 8273  2017_09_24_anamlb_houmlb_1   492424  24/9/2017      ANA
#
#       final_away_runs  final_home_runs  inning top_bottom           batter  \
# 0                   0                3       1     bottom  George Springer
# 1                   0                3       1     bottom  George Springer
# 2                   0                3       1     bottom  George Springer
# 3                   0                3       1     bottom  George Springer
# 4                   0                3       1     bottom     Alex Bregman
# ...               ...              ...     ...        ...              ...
# 8269                7                5       9     bottom      Jose Altuve
# 8270                7                5       9     bottom      Jose Altuve
# 8271                7                5       9     bottom      Jose Altuve
# 8272                7                5       9     bottom      Jose Altuve
# 8273                7                5       9     bottom      Jose Altuve
#
#      at_bat_event  ...   youtube_id pitch_youtube_seconds  \
# 0        Home Run  ...  af5e55Cc8ZA                  1473
# 1        Home Run  ...  af5e55Cc8ZA                  1489
# 8273  121bea48-7a5d-44e5-b71a-0f16033fc71a          108          117
#
# [8274 rows x 29 columns]

# %% [markdown]
# ## All unique players in the dataset directly above which will be used to pull out the individual players statistics

# %%
df2.batter.unique()
# Out:
# array(['George Springer', 'Alex Bregman', 'Jose Altuve', 'Carlos Correa',
#        'Carlos Beltran', 'Josh Reddick', 'Yuli Gurriel', 'Brian McCann',
#        'Norichika Aoki', 'Evan Gattis', 'Marwin Gonzalez',
#        'Jake Marisnick', 'Juan Centeno', 'Derek Fisher', 'Tyler White',
#        'AJ Reed', 'J.D. Davis', 'Max Stassi', 'Cameron Maybin',
#        'Tony Kemp'], dtype=object)

# %%
df2['batter'].value_counts()
# Out:
# George Springer    933
# Jose Altuve        866
# Alex Bregman       800
# Marwin Gonzalez    776
# Carlos Beltran     762
# Josh Reddick       725
# Yuli Gurriel       670
# Carlos Correa      594
# Brian McCann       507
# Evan Gattis        427
# Jake Marisnick     364
# Norichika Aoki     261
# Derek Fisher       211
# Tyler White        106
# Juan Centeno        65
# Cameron Maybin      56
# Max Stassi          52
# J.D. Davis          49
# AJ Reed             27
# Tony Kemp           23
# Name: batter, dtype: int64

# %%
springer = df2.loc[df2["batter"] == 'George Springer']
bregman = df2.loc[df2["batter"] == 'Alex Bregman']
altuve = df2.loc[df2["batter"] == 'Jose Altuve']
correa = df2.loc[df2["batter"] == 'Carlos Correa']
beltran = df2.loc[df2["batter"] == 'Carlos Beltran']
reddick = df2.loc[df2["batter"] == 'Josh Reddick']
gurriel = df2.loc[df2["batter"] == 'Yuli Gurriel']
mccann = df2.loc[df2["batter"] == 'Brian McCann']
aoki = df2.loc[df2["batter"] == 'Norichika Aoki']
gattis = df2.loc[df2["batter"] == 'Evan Gattis']
gonzalez = df2.loc[df2["batter"] == 'Marwin Gonzalez']
marisnick = df2.loc[df2["batter"] == 'Jake Marisnick']
centeno = df2.loc[df2["batter"] == 'Juan Centeno']
fisher = df2.loc[df2["batter"] == 'Derek Fisher']
white = df2.loc[df2["batter"] == 'Tyler White']
reed = df2.loc[df2["batter"] == 'AJ Reed']
davis = df2.loc[df2["batter"] == 'J.D. Davis']
stassi = df2.loc[df2["batter"] == 'Max Stassi']
maybin = df2.loc[df2["batter"] == 'Cameron Maybin']
kemp = df2.loc[df2["batter"] == 'Tony Kemp']

# %% [markdown]
# # George Springer Analysis Section

# %%
plt.plot_date(springer['game_date'], springer['AB'], '-')
xticks([3, 27, 56, 83, 107, 135, 162], ['April', 'May', 'June', 'July', 'August', 'September', 'October'])
plt.title('Date vs. At-Bats (AB)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('At-Bats (AB)', fontsize = 20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/sources/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AB'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-4a2d86cc6267> in <module>
# ----> 1 plt.plot_date(springer['game_date'], springer['AB'], '-')
#       2 xticks([3, 27, 56, 83, 107, 135, 162], ['April', 'May', 'June', 'July', 'August', 'September', 'October'])
#       3 plt.title('Date vs. At-Bats (AB)', fontsize = 30)
#       4 plt.xlabel('Date', fontsize = 20)
#       5 plt.ylabel('At-Bats (AB)', fontsize = 20)
#
# ~/opt/anaconda3/envs/sources/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/sources/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AB'
