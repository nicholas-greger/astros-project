# %% [markdown]
# # Milestone for Cheating in Baseball
# Andy Hanson u0772196@utah.edu
# Nicholas Forbes
# Nik Greger

# %% [markdown]
# # What we have done

# %% [markdown]
# so fair we have collected most of the data we will need to preform our analysis. we may use more seasons stats but its available and in the same format of the data we have already collected. so we can use the same code to clean and format the new data if needed. we have made graphs for the main stats in the 2017 season marked where the known cheating begins and ends and have used these visuals to confirm our hypothesis as plausible that it seems there is a signifcant uptick in batting stats for the astros that matches up with the start of the sign stealing.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import xticks
plt.rcParams['figure.figsize'] = (30,15)

# %%
df1 = pd.read_csv('astros batting data 2017.csv')
df1
# Out:
#       Rk  Gtm    Date Unnamed: 3  Opp    Rslt  PA  AB   R   H  ...  SB  CS  \
# 0      1    1   3-Apr        NaN  SEA   W,3-0  30  27   3   6  ...   1   0
# 1      2    2   4-Apr        NaN  SEA   W,2-1  29  26   2   5  ...   0   2
# 2      3    3   5-Apr        NaN  SEA   W,5-3  55  51   5  13  ...   0   0
# 3      4    4   6-Apr        NaN  SEA   L,2-4  36  32   2   6  ...   0   0
# 4      5    5   7-Apr        NaN  KCR   L,1-5  33  30   1   6  ...   0   0
# ..   ...  ...     ...        ...  ...     ...  ..  ..  ..  ..  ...  ..  ..
# 157  158  158  27-Sep          @  TEX  W,12-2  45  43  12  16  ...   0   0
# 158  159  159  28-Sep          @  BOS  W,12-2  50  44  12  17  ...   0   0
# 159  160  160  29-Sep          @  BOS   W,3-2  36  33   3   6  ...   0   1
# 160  161  161  30-Sep          @  BOS   L,3-6  37  33   3   8  ...   0   1
# 161  162  162   1-Oct          @  BOS   W,4-3  38  33   4   8  ...   1   0
#
#         BA    OBP    SLG    OPS  LOB   #  Thr  Opp. Starter (GmeSc)
# ...

# %%
plt.plot_date(df1['Date'], df1['BA'], '-')
df1.BA.rolling(10).mean().plot()
plt.axvline(x=50, color = 'red',ls ='--')
plt.axvline(x=152, color = 'red',ls ='--')
xticks([3, 27,50, 56, 83, 107, 135, 152, 162], ['April', 'May', 'Cheating Begins', 'June', 'July', 'August', 'September','Cheating Ends', 'October'])
plt.title('Date vs. Batting Average (BA)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Batting Average (BA)', fontsize = 20)
# Out:
# Text(0, 0.5, 'Batting Average (BA)')

# %%
print(df1['BA'].mean())
# Out:
# 0.2773395061728392

# %% [markdown]
# ## An obvious increase in the Batting Average occurs around the same time as the sign stealing campaign began. This is one initial observation that could have a serious foundation in the logic of the cheating scandal.

# %%
plt.plot_date(df1['Date'], df1['RBI'], '-')
df1.RBI.rolling(6).mean().plot()
plt.axvline(x=50, color = 'red',ls ='--')
plt.axvline(x=152, color = 'red',ls ='--')
xticks([3, 27,50, 56, 83, 107, 135, 152, 162], ['April', 'May', 'Cheating Begins', 'June', 'July', 'August', 'September','Cheating Ends', 'October'])
plt.title('Date vs. Runs Batted In (RBI)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Runs Batted In (RBI)', fontsize = 20)
# Out:
# Text(0, 0.5, 'Runs Batted In (RBI)')

# %%
print(df1['RBI'].mean())

# %% [markdown]
# ## RBIs seemed to increase in the middle of the season but also died off a bit as the playoffs approached.

# %%
plt.plot_date(df1['Date'], df1['H'], '-')
df1.H.rolling(5).mean().plot()
plt.axvline(x=50, color = 'red',ls ='--')
plt.axvline(x=152, color = 'red',ls ='--')
xticks([3, 27,50, 56, 83, 107, 135, 152, 162], ['April', 'May', 'Cheating Begins', 'June', 'July', 'August', 'September','Cheating Ends', 'October'])
plt.title('Date vs. Hits (H)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Hits (H)', fontsize = 20)
# Out:
# Text(0, 0.5, 'Hits (H)')

# %%
print(df1['H'].mean())

# %% [markdown]
# ## The number of hits increased around the May 21st scandal beginning and remained relatively consistent for the remainder of the season.

# %%
plt.plot_date(df1['Date'], df1['OBP'],)
df1.OBP.rolling(5).mean().plot()
plt.axvline(x=50, color = 'red',ls ='--')
plt.axvline(x=152, color = 'red',ls ='--')
xticks([3, 27,50, 56, 83, 107, 135, 152, 162], ['April', 'May', 'Cheating Begins', 'June', 'July', 'August', 'September','Cheating Ends', 'October'])
plt.title('Date vs. On Base Percentage (OBP)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('On Base Percentage (OBP)', fontsize = 20)
# Out:
# Text(0, 0.5, 'On Base Percentage (OBP)')

# %%
print(df1['OBP'].mean())

# %% [markdown]
# ## Seeing as how the cheating began around May 21st, it is interesting how the rest of the season is relatively consistent when compared to the beginning of the season. Could this be a product of cheating or just finding more consistency with a team throughout a season?

# %%
plt.plot_date(df1['Date'], df1['AB'], '-')
df1.AB.rolling(5).mean().plot()
plt.axvline(x=50, color = 'red',ls ='--')
plt.axvline(x=152, color = 'red',ls ='--')
xticks([3, 27,50, 56, 83, 107, 135, 152, 162], ['April', 'May', 'Cheating Begins', 'June', 'July', 'August', 'September','Cheating Ends', 'October'])
plt.title('Date vs. At-Bats (AB)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('At-Bats (AB)', fontsize = 20)
# Out:
# Text(0, 0.5, 'At-Bats (AB)')

# %%
print(df1['AB'].mean())
# Out:
# 34.635802469135804

# %%
df2 = pd.read_csv('astros_bangs_20200127.csv')
df2['DATE'] = pd.to_datetime(df2['game_date'])
df2.has_bangs[df2.has_bangs == 'y'] = 1
df2.has_bangs[df2.has_bangs == 'n'] =0
# Out:
# C:\Users\hanso\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\hanso\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## All unique players in the dataset directly above which will be used to pull out the individual players statistics

# %%
df2.batter.unique()
# Out:
# array(['George Springer', 'Alex Bregman', 'Jose Altuve', 'Carlos Correa',
#        'Carlos Beltran', 'Josh Reddick', 'Yuli Gurriel', 'Brian McCann',
#        'Norichika Aoki', 'Evan Gattis', 'Marwin Gonzalez',
#        'Jake Marisnick', 'Juan Centeno', 'Derek Fisher', 'Tyler White',
#        'AJ Reed', 'J.D. Davis', 'Max Stassi', 'Cameron Maybin',
#        'Tony Kemp'], dtype=object)

# %%
df2['batter'].value_counts()
# Out:
# George Springer    933
# Jose Altuve        866
# Alex Bregman       800
# Marwin Gonzalez    776
# Carlos Beltran     762
# Josh Reddick       725
# Yuli Gurriel       670
# Carlos Correa      594
# Brian McCann       507
# Evan Gattis        427
# Jake Marisnick     364
# Norichika Aoki     261
# Derek Fisher       211
# Tyler White        106
# Juan Centeno        65
# Cameron Maybin      56
# Max Stassi          52
# J.D. Davis          49
# AJ Reed             27
# Tony Kemp           23
# Name: batter, dtype: int64

# %%
springer = df2.loc[df2["batter"] == 'George Springer']
bregman = df2.loc[df2["batter"] == 'Alex Bregman']
altuve = df2.loc[df2["batter"] == 'Jose Altuve']
correa = df2.loc[df2["batter"] == 'Carlos Correa']
beltran = df2.loc[df2["batter"] == 'Carlos Beltran']
reddick = df2.loc[df2["batter"] == 'Josh Reddick']
gurriel = df2.loc[df2["batter"] == 'Yuli Gurriel']
mccann = df2.loc[df2["batter"] == 'Brian McCann']
aoki = df2.loc[df2["batter"] == 'Norichika Aoki']
gattis = df2.loc[df2["batter"] == 'Evan Gattis']
gonzalez = df2.loc[df2["batter"] == 'Marwin Gonzalez']
marisnick = df2.loc[df2["batter"] == 'Jake Marisnick']
centeno = df2.loc[df2["batter"] == 'Juan Centeno']
fisher = df2.loc[df2["batter"] == 'Derek Fisher']
white = df2.loc[df2["batter"] == 'Tyler White']
reed = df2.loc[df2["batter"] == 'AJ Reed']
davis = df2.loc[df2["batter"] == 'J.D. Davis']
stassi = df2.loc[df2["batter"] == 'Max Stassi']
maybin = df2.loc[df2["batter"] == 'Cameron Maybin']
kemp = df2.loc[df2["batter"] == 'Tony Kemp']

# %% [markdown]
# # George Springer Analysis Section

# %%
plt.plot_date(springer['DATE'], springer.AB, '-')
xticks([3, 27, 56, 83, 107, 135, 162], ['April', 'May', 'June', 'July', 'August', 'September', 'October'])
plt.title('Date vs. At-Bats (AB)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('At-Bats (AB)', fontsize = 20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-4ed29b99d10c> in <module>
# ----> 1 plt.plot_date(springer['DATE'], springer.AB, '-')
#       2 xticks([3, 27, 56, 83, 107, 135, 162], ['April', 'May', 'June', 'July', 'August', 'September', 'October'])
#       3 plt.title('Date vs. At-Bats (AB)', fontsize = 30)
#       4 plt.xlabel('Date', fontsize = 20)
#       5 plt.ylabel('At-Bats (AB)', fontsize = 20)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'AB'

# %%
pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)

# %%
df1
df1["Unnamed: 3"] = df1['Unnamed: 3'].fillna(1)
df1["Unnamed: 3"] = df1['Unnamed: 3'].replace("@",0)
df1 = df1.rename(columns={"Unnamed: 3": "Home_Game"})

# %%
df1
# Out:
#       Rk  Gtm    Date  Home_Game  Opp    Rslt  PA  AB   R   H  ...  SB  CS  \
# 0      1    1   3-Apr          1  SEA   W,3-0  30  27   3   6  ...   1   0
# 1      2    2   4-Apr          1  SEA   W,2-1  29  26   2   5  ...   0   2
# 2      3    3   5-Apr          1  SEA   W,5-3  55  51   5  13  ...   0   0
# 3      4    4   6-Apr          1  SEA   L,2-4  36  32   2   6  ...   0   0
# 4      5    5   7-Apr          1  KCR   L,1-5  33  30   1   6  ...   0   0
# ..   ...  ...     ...        ...  ...     ...  ..  ..  ..  ..  ...  ..  ..
# 157  158  158  27-Sep          0  TEX  W,12-2  45  43  12  16  ...   0   0
# 158  159  159  28-Sep          0  BOS  W,12-2  50  44  12  17  ...   0   0
# 159  160  160  29-Sep          0  BOS   W,3-2  36  33   3   6  ...   0   1
# 160  161  161  30-Sep          0  BOS   L,3-6  37  33   3   8  ...   0   1
# 161  162  162   1-Oct          0  BOS   W,4-3  38  33   4   8  ...   1   0
#
#         BA    OBP    SLG    OPS  LOB   #  Thr  Opp. Starter (GmeSc)
# ...

# %%
df1.dtypes
# Out:
# Rk                        int64
# Gtm                       int64
# Date                     object
# Home_Game                 int64
# Opp                      object
# Rslt                     object
# PA                        int64
# AB                        int64
# R                         int64
# H                         int64
# 2B                        int64
# 3B                        int64
# HR                        int64
# RBI                       int64
# BB                        int64
# IBB                       int64
# SO                        int64
# HBP                       int64
# SH                        int64
# SF                        int64
# ROE                       int64
# GDP                       int64
# SB                        int64
# CS                        int64
# BA                      float64
# OBP                     float64
# SLG                     float64
# OPS                     float64
# LOB                       int64
# ...

# %%
df_home = df1[df1['Home_Game'] >= 1]
df_away = df1[df1['Home_Game'] < 1]

# %% [markdown]
# # Graphs comparing Home vs Away games for the 2017 season

# %%
plt.plot(df_home['Rk'], df_home['RBI'], '-', c = 'blue')
plt.axvline(x=50, color = 'red',ls ='--')
plt.axvline(x=152, color = 'red',ls ='--')
xticks([3, 27,50, 56, 83, 107, 135, 152, 162], ['April', 'May', 'Cheating Begins', 'June', 'July', 'August', 'September','Cheating Ends', 'October'])
plt.title('Date vs. Runs Batted In (RBI)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Runs Batted In (RBI)', fontsize = 20)

plt.plot(df_away['Rk'], df_away['RBI'], '-', c = 'green')

# %%
plt.plot(df_home['Rk'], df_home['H'], '-', c = 'blue')
plt.axvline(x=50, color = 'red',ls ='--')
plt.axvline(x=152, color = 'red',ls ='--')
xticks([3, 27,50, 56, 83, 107, 135, 152, 162], ['April', 'May', 'Cheating Begins', 'June', 'July', 'August', 'September','Cheating Ends', 'October'])
plt.title('Date vs. Hits (H)', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Hits (H)', fontsize = 20)

plt.plot(df_away['Rk'], df_away['H'], '-', c = 'green')

# %%
plt.plot(df_home['Rk'], df_home['BA'], '-', c = 'blue')
plt.axvline(x=50, color = 'red',ls ='--')
plt.axvline(x=152, color = 'red',ls ='--')
xticks([3, 27,50, 56, 83, 107, 135, 152, 162], ['April', 'May', 'Cheating Begins', 'June', 'July', 'August', 'September','Cheating Ends', 'October'])
plt.title('Date vs. Batting Average', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('Batting Average (BA)', fontsize = 20)

plt.plot(df_away['Rk'], df_away['BA'], '-', c = 'green')

# %%
plt.plot(df_home['Rk'], df_home['OBP'], '-', c = 'blue')
plt.axvline(x=50, color = 'red',ls ='--')
plt.axvline(x=152, color = 'red',ls ='--')
xticks([3, 27,50, 56, 83, 107, 135, 152, 162], ['April', 'May', 'Cheating Begins', 'June', 'July', 'August', 'September','Cheating Ends', 'October'])
plt.title('Date vs. OBS for Home Games', fontsize = 30)
plt.xlabel('Date', fontsize = 20)
plt.ylabel('On Base %', fontsize = 20)
# Out:
# Text(0, 0.5, 'On Base %')

# %% [markdown]
# # Plan Going Forward

# %% [markdown]
# These graphs show that it seems plausible that sign stealing helped the astros win more games becasue there is an uptick in
# almost all batting stats starting around the same time the sign stealing began. If you look at the rolling average for each
# stat you it seems there are peaks and valleys it would be intresting to see how much these variations in the rolling average
# align with home game series vs away game series. We really liked your suggestion for using surprived learning with sign
# stealing as labels and plan to implement it. We are also going to use a bayesian model to prediect players expected batting stats for the 2017 season using previous seasons data. compare the predicted model vs actual stats and see if any of the players had a drastic improvement that were not expected. We will also try to focus more on the players who used the sign stealing more often as we expect their stats to increase more since they were cheating more often.
